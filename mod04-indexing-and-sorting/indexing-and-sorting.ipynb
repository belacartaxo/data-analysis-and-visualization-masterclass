# %% [markdown]
# # Indexing and sorting

# %% [markdown]
# ## Indexing
#
# ### Setting an Index
# - `set_index(column_name, inplace=False)`: Sets the specified column as the DataFrame's index.
#   - Example: `table.set_index("column", inplace=True)`
#
# - `pd.read_csv(filepath, index_col=column_name)`: Reads a CSV file and sets the specified column as the index during import.
#   - Example:
#     ```python
#     table = pd.read_csv('data.csv', index_col="column")
#     ```

# %%
import pandas as pd 
btc = pd.read_csv("../data/coin_Bitcoin.csv")

# %%
btc.set_index("Date", inplace=True)

# %%
btc
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
hr = pd.read_csv('../data/world-happiness-report-2021.csv')
hr['Healthy life expectancy']
# Out:
# 0      72.000
# 1      72.700
# 2      74.400
# 3      73.000
# 4      72.400
#         ...
# 144    48.700
# 145    59.269
# 146    61.400
# 147    56.201
# 148    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
hr.set_index("Country name", inplace=True)

# %%
hr['Healthy life expectancy']
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
hr['Healthy life expectancy'].head(25).plot()
# Out:
# <Axes: xlabel='Country name'>

# %% [markdown]
# ## Sorting
#
# ### Sorting by Values
# - `sort_values(by, ascending=True, key=None)`: Sorts the DataFrame by one or more columns.
#   - Single column: `table.sort_values("column", ascending=False)`
#   - Multiple columns: `table.sort_values(["column1", "column2"], ascending=True)`
#   - Using a custom function: `table.sort_values("column", key=lambda col: col.str.lower())`
#
# #### Case Sensitivity in Sorting Strings
#
# When sorting strings, the method differentiates between uppercase and lowercase letters. By default:
# - Uppercase letters are sorted before lowercase letters due to their ASCII values.
#
# To perform case-insensitive sorting, use the key parameter with a function like str.lower
#
# `table.sort_values("column", key=lambda col: col.str.lower())`
#
# ### Sorting by Index
# - `sort_index(inplace=False)`: Sorts the DataFrame by its index.
#   - Example: `table.sort_index(inplace=True)`

# %%
hr = pd.read_csv('../data/world-happiness-report-2021.csv', index_col="Country name")
hr['Healthy life expectancy']
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
hr = pd.read_csv('../data/world-happiness-report-2021.csv', index_col=0)
hr['Healthy life expectancy']
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
hr.sort_values("Healthy life expectancy", ascending=False)
# Out:
#                            Regional indicator  Ladder score  \
# Country name
# Singapore                      Southeast Asia         6.377
# Hong Kong S.A.R. of China           East Asia         5.477
# Japan                               East Asia         5.940
# Spain                          Western Europe         6.491
# Switzerland                    Western Europe         7.571
# ...                                       ...           ...
# Swaziland                  Sub-Saharan Africa         4.308
# Ivory Coast                Sub-Saharan Africa         5.306
# Nigeria                    Sub-Saharan Africa         4.759
# Lesotho                    Sub-Saharan Africa         3.512
# Chad                       Sub-Saharan Africa         4.355
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Singapore                                           0.043         6.460
# ...

# %%
houses = pd.read_csv('../data/kc_house_data.csv')
titanic = pd.read_csv('../data/titanic.csv')

# %%
houses.sort_values(["bedrooms", "bathrooms"], ascending=False)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 19254  8812401450  20141229T000000   660000.0        10       3.00
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# ...           ...              ...        ...       ...        ...
# 6994   2954400190  20140624T000000  1295650.0         0       0.00
# 9773   3374500520  20150429T000000   355000.0         0       0.00
# 9854   7849202190  20141223T000000   235000.0         0       0.00
# 14423  9543000205  20150413T000000   139950.0         0       0.00
# 19452  3980300371  20140926T000000   142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
# ...

# %%
titanic.sort_values("name", key = lambda col: col.str.lower())
# Out:
#       pclass  survived                              name     sex   age  sibsp  \
# 600        3         0               Abbing, Mr. Anthony    male    42      0
# 601        3         0     Abbott, Master. Eugene Joseph    male    13      0
# 602        3         0       Abbott, Mr. Rossmore Edward    male    16      1
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female    35      1
# 604        3         1       Abelseth, Miss. Karen Marie  female    16      0
# ...      ...       ...                               ...     ...   ...    ...
# 1304       3         0              Zabour, Miss. Hileni  female  14.5      1
# 1305       3         0             Zabour, Miss. Thamine  female     ?      1
# 1306       3         0         Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3         0               Zakarian, Mr. Ortin    male    27      0
# 1308       3         0                Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
hr.sort_index(inplace=True)

# %%
titanic.pclass.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>

# %% [markdown]
# ## Selecting Data
#
# ### Row Selection
# - `loc`: Label-based indexing.
#   - Single row as a Series: `table.loc["label"]`
#   - Single row as a DataFrame: `table.loc[["label"]]`
#   - Multiple rows: `table.loc[["label1", "label2"]]`
#   - Slicing with steps: `table.loc[start_label:end_label:step]`
#
# - `iloc`: Position-based indexing.
#   - Specific rows by position: `table.iloc[[i, j, k]]`
#   - Slice by index range: `table.iloc[start:end]`
#
# ### Row and Column Selection
# - `loc` with rows and specific columns:
#   - Example: `table.loc[start_label:end_label, ['column1', 'column2']]`
#
# ### Difference Between `loc` and `iloc`
#
# - **`loc`**:
#   - Label-based indexing.
#   - Used to select rows and columns by their labels or a boolean array.
#   - Example: `table.loc["row_label", "column_label"]`
#
# - **`iloc`**:
#   - Position-based indexing.
#   - Used to select rows and columns by their integer positions.
#   - Example: `table.iloc[0, 1]`
#
# **Key Difference**:
# - `loc` uses explicit labels from the index and column names.
# - `iloc` uses numerical indices based on the row and column order.

# %%
hr.loc["Yemen"]
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         3.658
# Standard error of ladder score                                        0.07
# upperwhisker                                                         3.794
# lowerwhisker                                                         3.521
# Logged GDP per capita                                                7.578
# Social support                                                       0.832
# Healthy life expectancy                                             57.122
# Freedom to make life choices                                         0.602
# Generosity                                                          -0.147
# Perceptions of corruption                                              0.8
# Ladder score in Dystopia                                              2.43
# ...

# %%
hr.loc[["Yemen"]]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Yemen         Middle East and North Africa         3.658
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Yemen                                   0.07         3.794         3.521
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Yemen                         7.578           0.832                   57.122
#
#               Freedom to make life choices  Generosity  \
# Country name
# Yemen                                0.602      -0.147
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Yemen                               0.8                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Yemen                                    0.329                         0.831
#
# ...

# %%
hr.loc[["Yemen", "Mexico"]]
# Out:
#                         Regional indicator  Ladder score  \
# Country name
# Yemen         Middle East and North Africa         3.658
# Mexico         Latin America and Caribbean         6.317
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Yemen                                  0.070         3.794         3.521
# Mexico                                 0.053         6.420         6.213
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Yemen                         7.578           0.832                   57.122
# Mexico                        9.859           0.831                   68.597
#
#               Freedom to make life choices  Generosity  \
# Country name
# Yemen                                0.602      -0.147
# Mexico                               0.862      -0.147
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# ...

# %%
titanic.loc[5:10:2]
# Out:
#    pclass  survived                     name   sex age  sibsp  parch  \
# 5       1         1      Anderson, Mr. Harry  male  48      0      0
# 7       1         0   Andrews, Mr. Thomas Jr  male  39      0      0
# 9       1         0  Artagaveytia, Mr. Ramon  male  71      0      0
#
#      ticket     fare cabin embarked boat body            home.dest
# 5     19952    26.55   E12        S    3    ?         New York, NY
# 7    112050        0   A36        S    ?    ?          Belfast, NI
# 9  PC 17609  49.5042     ?        C    ?   22  Montevideo, Uruguay

# %%
hr.iloc[[10, 20, 30, 40]]
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Belarus       Commonwealth of Independent States         5.534
# Cambodia                          Southeast Asia         4.830
# Croatia               Central and Eastern Europe         5.882
# Finland                           Western Europe         7.842
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Belarus                                0.047         5.625         5.442
# Cambodia                               0.067         4.963         4.698
# Croatia                                0.048         5.975         5.788
# Finland                                0.032         7.904         7.780
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Belarus                       9.853           0.910                   66.253
# Cambodia                      8.360           0.765                   62.000
# ...

# %%
hr.iloc[50:55]
# Out:
#                                     Regional indicator  Ladder score  \
# Country name
# Haiti                      Latin America and Caribbean         3.615
# Honduras                   Latin America and Caribbean         5.919
# Hong Kong S.A.R. of China                    East Asia         5.477
# Hungary                     Central and Eastern Europe         5.992
# Iceland                                 Western Europe         7.554
#
#                            Standard error of ladder score  upperwhisker  \
# Country name
# Haiti                                               0.173         3.953
# Honduras                                            0.082         6.081
# Hong Kong S.A.R. of China                           0.049         5.573
# Hungary                                             0.047         6.085
# Iceland                                             0.059         7.670
#
#                            lowerwhisker  Logged GDP per capita  \
# Country name
# ...

# %%
houses.loc[21610:21612, ['price', 'bedrooms']]
# Out:
#           price  bedrooms
# 21610  402101.0         2
# 21611  400000.0         3
# 21612  325000.0         2
