# %% [markdown]
# # Adding and Removing Columns
#
# ## Dropping Columns
#
# To remove columns from a DataFrame, you can use the `drop()` method.
#
# ### Syntax
# - `df.drop(labels, axis=1, inplace=False)`
# - `labels`: Specifies the column(s) to drop. You can pass a single column name or a list of column names.
# - `axis=1`: Indicates that you're dropping columns (not rows, which would be `axis=0`).
# - `inplace=False`: If set to `True`, the operation modifies the DataFrame in place. If `False`, it returns a new DataFrame without the dropped columns.
#
# ### Example:
#
# 1. **Dropping a single column**:
#     ```python
#     btc.drop(labels="Symbol", axis=1, inplace=True)  # Removes the "Symbol" column from btc
#     ```
#
# 2. **Dropping multiple columns**:
#     ```python
#     btc.drop(labels=["column1", "column2"], axis=1, inplace=True)  # Removes multiple columns
#     ```
# 3. **Alternative syntax (using columns)**:
#     ```python
#     btc.drop(columns=["column1", "column2"])  # Removes the specified columns
#     ```

# %%
import pandas as pd
houses = pd.read_csv('../data/kc_house_data.csv')
titanic = pd.read_csv('../data/titanic.csv')
netflix = pd.read_csv('../data/netflix_titles.csv', sep="|", index_col=0)
btc = pd.read_csv('../data/coin_Bitcoin.csv')
countries = pd.read_csv('../data/world-happiness-report-2021.csv')

# %%
btc.drop(labels="Symbol", axis=1, inplace = True)
btc
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
btc.drop(labels=["SNo", "Name"], axis=1)
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc.drop(columns=["SNo", "Name"])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %% [markdown]
# ## Dropping Rows
#
# To remove rows from a DataFrame, you can use the `drop()` method.
#
# ### Syntax:
# - `df.drop(labels, axis=0, inplace=False)`
#   - `labels`: Specifies the row(s) to drop. You can pass a single label or a list of labels.
#   - `axis=0`: This is the default axis, so it doesn't need to be specified when dropping rows.
#   - `inplace=False`: If set to `True`, the operation modifies the DataFrame in place. If `False`, it returns a new DataFrame without the dropped rows.
#
# ### Examples:
#
# 1. **Dropping a row by label**:
#    ```python
#    countries.drop(labels="Denmark")  # Removes the row with the label "Denmark"
#     ```
# 2. **Dropping a row by default index**:
#     ```python
#     btc.drop(0)  # Removes the row at index 0
#     ```
# 3. **Dropping rows using a range of indices (when the index is not numeric)**:
#     ```python
#     countries.drop(countries.index[0:3])  # Removes rows with indices 0, 1, and 2
#     ```

# %%
countries.set_index("Country name", inplace=True)

countries.drop(labels="Denmark", axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(labels=["Denmark", "Iceland", "Finland"])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Switzerland       Western Europe         7.571
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Switzerland                            0.036         7.643         7.500
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %%
btc.drop(0)
# Out:
#        SNo     Name                 Date          High           Low  \
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# 5        6  Bitcoin  2013-05-04 23:59:59    115.000000     92.500000
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 1       144.000000    139.000000  0.000000e+00  1.542813e+09
# ...

# %%
countries.drop(countries.index[0:3])
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# Sweden            Western Europe         7.363
# Luxembourg        Western Europe         7.324
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Iceland                                0.059         7.670         7.438
# Netherlands                            0.027         7.518         7.410
# Norway                                 0.035         7.462         7.323
# ...

# %% [markdown]
# ## Adding Static Columns
#
# You can add new columns to a DataFrame in different ways, either by appending a static value or inserting a column at a specific position.
#
# ### 1. **Adding a column at the end of the DataFrame:**
#
# You can assign a value or a Series to a new column in the DataFrame. If you assign a single value, it will be applied to all rows.
#
# **Example:**
# ```python
# titanic["humans"] = "Human"  # Adds a new column "humans" with the value "Human" for all rows
# ```
#
# ### 2. **Inserting a column at a specific position**:
# You can use the insert() method to add a column at a specific position in the DataFrame. The first argument specifies the index where the column should be inserted, and the second argument is the column name. The third argument is the value to fill the column, which can be a single value or a Series.
#
# **Example**:
#
# ```python
# titanic.insert(0, "specie", "T-A")  # Adds a new column "specie" at the first position with the value "T-A"
# ```
# ### 3. **Adding a column with varied values**:
# Instead of a static value, you can also pass a Series with different values to a new column.
#
# **Example**:
#
# ```python
# titanic["age_group"] = [22, 34, 28, 41, 56]  # Adds a new column "age_group" with different values for each row
# ```

# %%
titanic["humans"] = "Human"
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.insert(0, "specie", "T-A")
titanic
# Out:
#      specie  pclass  survived  \
# 0       T-A       1         1
# 1       T-A       1         1
# 2       T-A       1         0
# 3       T-A       1         0
# 4       T-A       1         0
# ...     ...     ...       ...
# 1304    T-A       3         0
# 1305    T-A       3         0
# 1306    T-A       3         0
# 1307    T-A       3         0
# 1308    T-A       3         0
#
#                                                  name     sex     age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female      29      0
# 1                      Allison, Master. Hudson Trevor    male  0.9167      1
# 2                        Allison, Miss. Helen Loraine  female       2      1
# 3                Allison, Mr. Hudson Joshua Creighton    male      30      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25      1
# ...                                               ...     ...     ...    ...
# ...

# %%
titanic.insert(0, "new_class", titanic["pclass"])
titanic
# Out:
#       new_class specie  pclass  survived  \
# 0             1    T-A       1         1
# 1             1    T-A       1         1
# 2             1    T-A       1         0
# 3             1    T-A       1         0
# 4             1    T-A       1         0
# ...         ...    ...     ...       ...
# 1304          3    T-A       3         0
# 1305          3    T-A       3         0
# 1306          3    T-A       3         0
# 1307          3    T-A       3         0
# 1308          3    T-A       3         0
#
#                                                  name     sex     age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female      29      0
# 1                      Allison, Master. Hudson Trevor    male  0.9167      1
# 2                        Allison, Miss. Helen Loraine  female       2      1
# 3                Allison, Mr. Hudson Joshua Creighton    male      30      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25      1
# ...

# %% [markdown]
# ## Dynamic values

# %%
titanic["num_relatives"] = titanic["sibsp"] +titanic["parch"]
titanic
# Out:
#       new_class specie  pclass  survived  \
# 0             1    T-A       1         1
# 1             1    T-A       1         1
# 2             1    T-A       1         0
# 3             1    T-A       1         0
# 4             1    T-A       1         0
# ...         ...    ...     ...       ...
# 1304          3    T-A       3         0
# 1305          3    T-A       3         0
# 1306          3    T-A       3         0
# 1307          3    T-A       3         0
# 1308          3    T-A       3         0
#
#                                                  name     sex     age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female      29      0
# 1                      Allison, Master. Hudson Trevor    male  0.9167      1
# 2                        Allison, Miss. Helen Loraine  female       2      1
# 3                Allison, Mr. Hudson Joshua Creighton    male      30      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      25      1
# ...
